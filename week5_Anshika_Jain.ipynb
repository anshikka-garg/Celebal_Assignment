# %% [markdown]
# # 📘 Deep Learning Text Generation Learning Project
# ## Text Generation using **Vanilla RNN, LSTM, and GRU**
#
# This notebook is built for **students and beginners** to understand how sequence models learn:
# - grammar
# - sentence flow
# - contextual dependencies
# - next-word prediction
# - text generation
#
# 🎯 **Goal:** Compare **Simple RNN vs LSTM vs GRU** on the same text corpus and understand why gated architectures perform better.

# %% [markdown]
# # 🧠 Problem Statement
# Design and implement a DL model capable of learning the underlying structure, grammar, and contextual dependencies of a given text corpus to generate coherent and meaningful text sequences using:
#
# 1. **Vanilla RNN**
# 2. **LSTM**
# 3. **GRU**
#
# Then compare:
# - training loss
# - generated text quality
# - memory handling
# - long-term dependency learning

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
import numpy as np
import matplotlib.pyplot as plt
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 📥 Load Text Corpus
# We use a **small built-in sample corpus** so students can run this quickly.
# You can later replace it with:
# - Shakespeare text
# - song lyrics
# - chatbot data
# - story paragraphs
# - custom PDF extracted text

# %%
corpus = '''
deep learning is transforming artificial intelligence
recurrent neural networks are useful for sequential data
lstm helps remember long term dependencies
gru is faster and simpler than lstm
text generation models predict the next word
deep learning models can generate meaningful sentences
'''
print(corpus)
# Out:
# deep learning is transforming artificial intelligence
# recurrent neural networks are useful for sequential data
# lstm helps remember long term dependencies
# gru is faster and simpler than lstm
# text generation models predict the next word
# deep learning models can generate meaningful sentences

# %% [markdown]
# # 🔤 Tokenization & Sequence Creation
# We convert text into integer tokens and create **n-gram style sequences**
# for next-word prediction.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([corpus])

total_words = len(tokenizer.word_index) + 1
print("Vocabulary size:", total_words)

input_sequences = []
for line in corpus.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_seq = token_list[:i+1]
        input_sequences.append(n_gram_seq)

max_len = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# Vocabulary size: 37
# X shape: (35, 7)
# y shape: (35,)

# %% [markdown]
# # 🧠 Model 1: Vanilla RNN
# This is the baseline sequential model.
# It struggles with long-term dependencies because of vanishing gradients.

# %%
rnn_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    SimpleRNN(64),
    Dense(total_words, activation='softmax')
])

rnn_model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

rnn_history = rnn_model.fit(X, y, epochs=100, verbose=0)
print("Vanilla RNN training completed")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Vanilla RNN training completed

# %% [markdown]
# # 🔒 Model 2: LSTM
# LSTM uses **input, forget, and output gates**
# to preserve long-term memory.

# %%
lstm_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    LSTM(64),
    Dense(total_words, activation='softmax')
])

lstm_model.compile(loss='sparse_categorical_crossentropy',
                   optimizer='adam',
                   metrics=['accuracy'])

lstm_history = lstm_model.fit(X, y, epochs=100, verbose=0)
print("LSTM training completed")
# Out:
# LSTM training completed

# %% [markdown]
# # ⚡ Model 3: GRU
# GRU uses **reset + update gates**.
# It is computationally faster than LSTM and often gives similar results.

# %%
gru_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    GRU(64),
    Dense(total_words, activation='softmax')
])

gru_model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

gru_history = gru_model.fit(X, y, epochs=100, verbose=0)
print("GRU training completed")
# Out:
# GRU training completed

# %% [markdown]
# ## 📉 Compare Training Loss

# %%
plt.figure(figsize=(10,4))
plt.plot(rnn_history.history['loss'], label='RNN')
plt.plot(lstm_history.history['loss'], label='LSTM')
plt.plot(gru_history.history['loss'], label='GRU')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Comparison")
plt.legend()
plt.show()

# %% [markdown]
# # ✍️ Text Generation Function
# This function predicts the next word repeatedly to generate a sentence.

# %%
def generate_text(model, seed_text, next_words=5):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)[0]

        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# %% [markdown]
# ## 🧪 Generate Text Samples

# %%
print("RNN :", generate_text(rnn_model, "deep learning", 5))
print("LSTM:", generate_text(lstm_model, "deep learning", 5))
print("GRU :", generate_text(gru_model, "deep learning", 5))
# Out:
# RNN : deep learning is transforming artificial intelligence sentences
# LSTM: deep learning learning transforming generate meaningful meaningful
# GRU : deep learning is transforming artificial intelligence intelligence

# %% [markdown]
# # 📚 Student Learning Tasks
# ### ✅ Beginner Tasks
# 1. Replace corpus with your own paragraph
# 2. Increase embedding dimension
# 3. Increase epochs to 200
# 4. Change hidden units 64 → 128
# 5. Generate 10 words instead of 5

# %% [markdown]
# # ✅ Conclusion
# - **Vanilla RNN** learns short patterns but struggles with memory
# - **LSTM** captures long-range grammar dependencies better
# - **GRU** gives similar performance with fewer gates and faster training
# - This notebook helps students understand **sequence modeling mathematically and practically**

# %% [markdown]
# ## Task 1: Custom Corpus
# Replacing the original corpus with my own paragraph.

# %%
my_corpus = '''
recurrent neural networks process sequential data step by step
vanilla rnn struggles with long term dependencies due to vanishing gradients
lstm uses gates to control what information to remember or forget
gru is a simpler and faster alternative to lstm
hidden states carry memory of previous words in a sequence
deep learning models learn patterns directly from raw data
'''
print(my_corpus)
# Out:
# recurrent neural networks process sequential data step by step
# vanilla rnn struggles with long term dependencies due to vanishing gradients
# lstm uses gates to control what information to remember or forget
# gru is a simpler and faster alternative to lstm
# hidden states carry memory of previous words in a sequence
# deep learning models learn patterns directly from raw data

# %%
my_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    LSTM(64),
    Dense(total_words, activation='softmax')
])

my_model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

my_model.fit(X, y, epochs=100, verbose=0)
print("Training on custom corpus completed")
# Out:
# Training on custom corpus completed

# %%
def generate_text_custom(model, tok, seed_text, max_len_val, next_words=5):
    for _ in range(next_words):
        token_list = tok.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len_val-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)[0]
        output_word = ""
        for word, index in tok.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

print(generate_text_custom(my_model, tokenizer, "recurrent neural", max_len, 5))
# Out:
# recurrent neural is faster and for sequential

# %% [markdown]
# ## Task 2: Increase Embedding Dimension
# Changing embedding dimension

# %%
my_model_emb64 = Sequential([
    Embedding(total_words, 64, input_length=max_len-1),
    LSTM(64),
    Dense(total_words, activation='softmax')
])

my_model_emb64.compile(loss='sparse_categorical_crossentropy',
                        optimizer='adam',
                        metrics=['accuracy'])

my_model_emb64.fit(X, y, epochs=100, verbose=0)
print("Training with embedding_dim=64 completed")

print(generate_text_custom(my_model_emb64, tokenizer, "recurrent neural", max_len, 5))
# Out:
# Training with embedding_dim=64 completed
# recurrent neural networks are useful for for

# %% [markdown]
# ## Task 3: Increase Epochs to 200
#  epochs (100 → 200)

# %%
my_model_epoch200 = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    LSTM(64),
    Dense(total_words, activation='softmax')
])

my_model_epoch200.compile(loss='sparse_categorical_crossentropy',
                           optimizer='adam',
                           metrics=['accuracy'])

my_model_epoch200.fit(X, y, epochs=200, verbose=0)
print("Training with epochs=200 completed")

print(generate_text_custom(my_model_epoch200, tokenizer, "recurrent neural", max_len, 5))
# Out:
# Training with epochs=200 completed
# recurrent neural networks are useful for sequential

# %% [markdown]
# ## Task 4: Change Hidden Units (64 → 128)
# Increasing the LSTM layer's hidden units from 64 to 128.

# %%
my_model_units128 = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    LSTM(128),
    Dense(total_words, activation='softmax')
])

my_model_units128.compile(loss='sparse_categorical_crossentropy',
                           optimizer='adam',
                           metrics=['accuracy'])

my_model_units128.fit(X, y, epochs=100, verbose=0)
print("Training with hidden_units=128 completed")

print(generate_text_custom(my_model_units128, tokenizer, "recurrent neural", max_len, 5))
# Out:
# Training with hidden_units=128 completed
# recurrent neural networks are useful for data

# %% [markdown]
# ## Task 5: Generate 10 Words Instead of 5
# Increasing next_words from 5 to 10.

# %%
print(generate_text_custom(my_model, tokenizer, "recurrent neural", max_len, 10))
# Out:
# recurrent neural is faster and for sequential data lstm lstm word word

# %% [markdown]
# ## SUMMARY
#
# 1. Custom corpus replacement worked, but the small dataset (6 lines) limited grammatical accuracy — "recurrent neural is faster and for sequential"
# 2. Increasing embedding dimension (32→64) improved coherence but introduced word repetition — "are useful for for"
# 3. Increasing epochs (100→200) gave the most coherent output of all tasks — "are useful for sequential," showing longer training helped the model converge better
# 4. Increasing hidden units (64→128) gave a correct but shorter completion — "are useful for data," with no major improvement over the baseline
# 5. Generating 10 words instead of 5 exposed the model's weakest point — it degraded into disconnected word repeats ("lstm lstm word word"), since errors compound with each additional predicted word
# 6. Across tasks, the biggest single improvement came from more training (epochs), while embedding size and hidden units gave mixed, dataset-limited results
# 7. The smaller and more repetitive the corpus, the faster greedy decoding (argmax) breaks down over longer generations — a core limitation of this generation approach
